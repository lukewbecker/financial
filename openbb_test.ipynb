# %%
from openbb_terminal.sdk import openbb
# Out:
# C:\Users\direc\anaconda3\envs\portfolio\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\direc\anaconda3\envs\portfolio\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# C:\Users\direc\anaconda3\envs\portfolio\lib\site-packages\numpy\.libs\libopenblas.JPIJNSWNNAN3CE6LLI5FWSPHUT2VXMTH.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
help(openbb.stocks.dd)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 help(openbb.stocks.dd)
#
# File ~\anaconda3\envs\portfolio\lib\site-packages\openbb_terminal\core\sdk\sdk_helpers.py:123, in Category.__getattribute__(self, name)
#     119 def __getattribute__(self, name: str):
#     120     """We override the __getattribute__ method and wrap all callable
#     121     attributes with a wrapper that logs the call and the result.
#     122     """
# --> 123     attr = super().__getattribute__(name)
#     124     if isinstance(attr, Operation) or name.startswith("__"):
#     125         return attr
#
# AttributeError: 'StocksController' object has no attribute 'dd'

# %%
openbb.economy.events()
# Out:
#   Time (ET)    Country                                  Event Actual  \
# 0     11:00  Euro Zone                  ECB's Schnabel Speaks      -
# 1     19:50      Japan  Corporate Services Price Index (CSPI)      -
# 2     21:30      China             Chinese Industrial profit       -
# 3     21:30      China          Chinese Industrial profit YTD      -
#
#   Consensus Previous        Date
# 0         -        -  2023-03-26
# 1      1.5%     1.6%  2023-03-26
# 2         -    0.80%  2023-03-26
# 3         -    -4.0%  2023-03-26

# %%
openbb.stocks.ca.screener(similar = ['AAPL', 'NFLX', 'META', 'AMZN', 'MSFT', 'GOOGL', 'DIS', 'TSLA'], data_type = 'valuation')
# Out:
#   Ticker    Market Cap    P/E  Fwd P/E   PEG    P/S    P/B    P/C    P/FCF  \
# 0   AAPL  2.514580e+12  27.23    24.25  3.35   6.49  44.89  48.96    30.44
# 1   AMZN  1.011510e+12    NaN    39.02   NaN   1.97   6.87  14.44      NaN
# 2    DIS  1.750600e+11  51.75    17.11  2.51   2.07   1.79  20.67  1862.37
# 3  GOOGL  1.356360e+12  23.50    17.27  1.52   4.80   5.31  11.92    22.60
# 4   META  5.296200e+11  24.65    17.08  6.21   4.54   4.32  13.00    27.81
# 5   MSFT  2.066850e+12  31.19    26.10  2.62  10.13  11.41  20.77    50.84
# 6   NFLX  1.426800e+11  35.94    22.83  2.25   4.51   7.04  23.55    88.15
# 7   TSLA  6.082000e+11  52.53    34.82  4.45   7.47  13.46  27.42    41.32
#
#    EPS this Y  EPS next Y  EPS past 5Y  EPS next 5Y  Sales past 5Y   Price  \
# 0       0.089      0.1078        0.216       0.0813          0.115  160.25
# 1      -1.082      1.7337       -0.260          NaN          0.236   98.13
# 2       0.578      0.3272       -0.210       0.2064          0.085   94.08
# 3      -0.239      0.2011        0.217       0.1551          0.206  105.44
# 4      -0.417      0.2346        0.054       0.0397          0.235  206.01
# 5       0.198      0.1482        0.243       0.1190          0.155  280.57
# 6      -0.144      0.2528        0.449       0.1597          0.220  328.39
# 7       1.217      0.3998        0.399       0.1180          0.473  190.41
#
#    Change       Volume
# 0  0.0083   57177618.0
# 1 -0.0059   55888956.0
# 2 -0.0183    9529564.0
# 3 -0.0015   30363998.0
# 4  0.0085   27679831.0
# 5  0.0105   28138552.0
# 6  0.0250   12978960.0
# 7 -0.0094  115847223.0
